# %% [markdown]
# # One step univariate model - ARIMA
#
# In this notebook, we demonstrate how to:
# - prepare time series data for training an ARIMA times series forecasting model
# - implement a simple ARIMA model to forecast the next HORIZON steps ahead (time *t+1* through *t+HORIZON*) in the time series
# - evaluate the model on a test dataset
#
#
# The data in this example is taken from the GEFCom2014 forecasting competition<sup>1</sup>. It consists of 3 years of hourly electricity load and temperature values between 2012 and 2014. The task is to forecast future values of electricity load. In this example, we show how to forecast one time step ahead, using historical load data only.
#
# <sup>1</sup>Tao Hong, Pierre Pinson, Shu Fan, Hamidreza Zareipour, Alberto Troccoli and Rob J. Hyndman, "Probabilistic energy forecasting: Global Energy Forecasting Competition 2014 and beyond", International Journal of Forecasting, vol.32, no.3, pp 896-913, July-September, 2016.

# %%
import sys
sys.path.append('..')
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math

from pandas.tools.plotting import autocorrelation_plot
from pyramid.arima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from common.utils import load_data, mape

# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
np.set_printoptions(precision=2)
warnings.filterwarnings("ignore") # specify to ignore warning messages

# Set for demo purposes (shorter run)
demo = False

# %% [markdown]
# Load the data from csv into a Pandas dataframe

# %%
energy = load_data('../data')[['load']]
energy.head()
# Out:
#                         load
# 2012-01-01 00:00:00 2,698.00
# 2012-01-01 01:00:00 2,558.00
# 2012-01-01 02:00:00 2,444.00
# 2012-01-01 03:00:00 2,402.00
# 2012-01-01 04:00:00 2,403.00

# %% [markdown]
# Plot all available load data (January 2012 to Dec 2014)

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# Plot first week of July 2014

# %%
energy['2014-07-01':'2014-07-07'].plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# ## Create training and testing data sets
#
# We separate our dataset into train and test sets. We train the model on the train set. After the model has finished training, we evaluate the model on the test set. We must ensure that the test set cover a later period in time from the training set, to ensure that the model does not gain from information from future time periods.
#
# We will allocate the period 1st September 2014 to 31st October to training set (2 months) and the period 1st November 2014 to 31st December 2014 to the test set (2 months). Since this is daily consumption of energy, there is a strong seasonal pattern, but the consumption is most similar to the consumption in the recent days. Therefore, using a relatively small window of time for training the data should be sufficient.

# %%
train_start_dt = '2014-10-01 00:00:00'

if(not demo):
    test_start_dt = '2014-11-01 00:00:00'
else: 
    test_start_dt = '2014-12-30 00:00:00'

# %%
energy[(energy.index < test_start_dt) & (energy.index >= train_start_dt)][['load']].rename(columns={'load':'train'}) \
    .join(energy[test_start_dt:][['load']].rename(columns={'load':'test'}), how='outer') \
    .plot(y=['train', 'test'], figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Our data preparation for the training set will involve the following steps:
#
# 1. Filter the original dataset to include only that time period reserved for the training set
# 2. Scale the time series such that the values fall within the interval (0, 1)

# %% [markdown]
# Create training set containing only the model features

# %%
train = energy.copy()[(energy.index >= train_start_dt) & (energy.index < test_start_dt)][['load']]
test = energy.copy()[energy.index >= test_start_dt][['load']]

print('Training data shape: ', train.shape)
print('Test data shape: ', test.shape)
# Out:
# Training data shape:  (744, 1)
# Test data shape:  (1464, 1)

# %% [markdown]
# Scale data to be in range (0, 1). This transformation should be calibrated on the training set only. This is to prevent information from the validation or test sets leaking into the training data.

# %%
scaler = MinMaxScaler()
train['load'] = scaler.fit_transform(train)
train.head(10)
# Out:
#                      load
# 2014-10-01 00:00:00  0.15
# 2014-10-01 01:00:00  0.11
# 2014-10-01 02:00:00  0.08
# 2014-10-01 03:00:00  0.08
# 2014-10-01 04:00:00  0.13
# 2014-10-01 05:00:00  0.28
# 2014-10-01 06:00:00  0.56
# 2014-10-01 07:00:00  0.71
# 2014-10-01 08:00:00  0.75
# 2014-10-01 09:00:00  0.78

# %% [markdown]
# Original vs scaled data:

# %%
energy[energy.index < train_start_dt][['load']].rename(columns={'load':'original load'}).plot.hist(bins=100, fontsize=12)
train.rename(columns={'load':'scaled load'}).plot.hist(bins=100, fontsize=12)
plt.show()

# %% [markdown]
# Let's also scale the test data

# %%
test['load'] = scaler.transform(test)
test.head()
# Out:
#                      load
# 2014-11-01 00:00:00  0.16
# 2014-11-01 01:00:00  0.11
# 2014-11-01 02:00:00  0.08
# 2014-11-01 03:00:00  0.08
# 2014-11-01 04:00:00  0.10

# %% [markdown]
# ## Implement ARIMA method

# %% [markdown]
# An ARIMA, which stands for **A**uto**R**egressive **I**ntegrated **M**oving **A**verage, model can be created using the statsmodels library. In the next section, we perform the following steps:
# 1. Define the model by calling SARIMAX() and passing in the model parameters: p, d, and q parameters, and P, D, and Q parameters.
# 2. The model is prepared on the training data by calling the fit() function.
# 3. Predictions can be made by calling the forecast() function and specifying the number of steps (horizon) which to forecast
#
# In an ARIMA model there are 3 parameters that are used to help model the major aspects of a times series: seasonality, trend, and noise. These parameters are:
# - **p** is the parameter associated with the auto-regressive aspect of the model, which incorporates past values.
# - **d** is the parameter associated with the integrated part of the model, which effects the amount of differencing to apply to a time series.
# - **q** is the parameter associated with the moving average part of the model.
#
# If our model has a seasonal component, we use a seasonal ARIMA model (SARIMA). In that case we have another set of parameters: P, D, and Q which describe the same associations as p,d, and q, but correspond with the seasonal components of the model.

# %%
# Specify the number of steps to forecast ahead
HORIZON = 3 if demo else 24

# %% [markdown]
# Let’s look at an autocorrelation plot of the time series. The example below plots the autocorrelation for 48 lags in the time series.

# %%
autocorrelation_plot(train[1:48])
plt.show()

# %% [markdown]
# We can see that there is a significant positive correlation with the first 4 or 5 lags. That may be a good starting point for the AR parameter (p) of the model.

# %% [markdown]
# The plot of energy load over time (see above) shows that the time series is not stationary due to its seasonality (daily peaks and also peaks in August and February due to the increased energy usage). This suggests the a certain degree of differencing the data might be necessary.

# %%
train['load'].diff(periods=24).plot(y='load', figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# Even after differencing the data by 24 hours (the seasonal frequency), we still see a seasonal trend in the data.
#
# Selecting the best parameters for an Arima model can be challenging - somewhat subjective and time intesive, so we'll leave it as an exercise to the user. We used an **auto_arima()** function to search a provided space of parameters for the best model.

# %%
# Model search takes a while, so don't run it during the demo
auto_tune = False

if (auto_tune):
    auto_model = auto_arima(train, start_p=1, start_q=0,
                               max_p=5, max_q=0, m=24,
                               start_P=0, max_P=2,Q=0, 
                               seasonal=True,
                               d=1, D=1, trace=True,
                               error_action='ignore',  
                               suppress_warnings=True, 
                               stepwise=True)
    print(auto_model.aic())
    print(auto_model.summary())

# %%
order = (4, 1, 0)
seasonal_order = (1, 1, 0, 24)

model = SARIMAX(endog=train, order=order, seasonal_order=seasonal_order)
results = model.fit()

print(results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                               load   No. Observations:                  744
# Model:             SARIMAX(4, 1, 0)x(1, 1, 0, 24)   Log Likelihood                1630.982
# Date:                            Fri, 28 Sep 2018   AIC                          -3249.965
# Time:                                    20:31:42   BIC                          -3222.498
# Sample:                                10-01-2014   HQIC                         -3239.360
#                                      - 10-31-2014
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7789      0.021     37.993      0.000       0.739       0.819
# ar.L2         -0.5345      0.041    -12.988      0.000      -0.615      -0.454
# ar.L3          0.1335      0.053      2.502      0.012       0.029       0.238
# ar.L4         -0.0871      0.047     -1.855      0.064      -0.179       0.005
# ar.S.L24      -0.1439      0.036     -3.968      0.000      -0.215      -0.073
# sigma2         0.0006   1.78e-05     35.138      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (Q):                       43.83   Jarque-Bera (JB):              1316.38
# Prob(Q):                              0.31   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                             0.41
# Prob(H) (two-sided):                  0.47   Kurtosis:                         9.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Next we display the distribution of residuals. A zero mean in the residuals may indicate that there is no bias in the prediction.

# %%
# plot residual errors
residuals = pd.DataFrame(results.resid[0:100])
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#            0
# count 100.00
# mean    0.00
# std     0.06
# min    -0.20
# 25%    -0.01
# 50%    -0.00
# 75%     0.02
# max     0.28

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# We will perform the so-called **walk forward validation**. In practice, time series models are re-trained each time a new data becomes available. This allows the model to make the best forecast at each time step.
#
# Starting at the beginning of the time series, we train the model on the train data set. Then we make a prediction on the next time step. The prediction is then evaluated against the known value. The training set is then expanded to include the known value and the process is repeated. (Note that we keep the training set window fixed, for more efficient training, so every time we add a new observation to the training set, we remove the observation from the beginning of the set.)
#
# This process provides a more robust estimation of how the model will perform in practice. However, it comes at the computation cost of creating so many models. This is acceptable if the data is small or if the model is simple, but could be an issue at scale.
#
# Walk-forward validation is the gold standard of time series model evaluation and is recommended for your own projects.

# %% [markdown]
# Create a test data point for each HORIZON step.

# %%
test_shifted = test.copy()

for t in range(1, HORIZON):
    test_shifted['load+'+str(t)] = test_shifted['load'].shift(-t, freq='H')
    
test_shifted = test_shifted.dropna(how='any')
test_shifted.head(5)
# Out:
#                      load  load+1  load+2  load+3  load+4  load+5  load+6  \
# 2014-11-01 00:00:00  0.16    0.11    0.08    0.08    0.10    0.16    0.28
# 2014-11-01 01:00:00  0.11    0.08    0.08    0.10    0.16    0.28    0.43
# 2014-11-01 02:00:00  0.08    0.08    0.10    0.16    0.28    0.43    0.57
# 2014-11-01 03:00:00  0.08    0.10    0.16    0.28    0.43    0.57    0.67
# 2014-11-01 04:00:00  0.10    0.16    0.28    0.43    0.57    0.67    0.72
#
#                      load+7  load+8  load+9   ...     load+14  load+15  \
# 2014-11-01 00:00:00    0.43    0.57    0.67   ...        0.69     0.70
# 2014-11-01 01:00:00    0.57    0.67    0.72   ...        0.70     0.75
# 2014-11-01 02:00:00    0.67    0.72    0.73   ...        0.75     0.82
# 2014-11-01 03:00:00    0.72    0.73    0.72   ...        0.82     0.84
# 2014-11-01 04:00:00    0.73    0.72    0.70   ...        0.84     0.76
#
#                      load+16  load+17  load+18  load+19  load+20  load+21  \
# 2014-11-01 00:00:00     0.75     0.82     0.84     0.76     0.68     0.56
# 2014-11-01 01:00:00     0.82     0.84     0.76     0.68     0.56     0.41
# 2014-11-01 02:00:00     0.84     0.76     0.68     0.56     0.41     0.27
# 2014-11-01 03:00:00     0.76     0.68     0.56     0.41     0.27     0.19
# 2014-11-01 04:00:00     0.68     0.56     0.41     0.27     0.19     0.12
#
#                      load+22  load+23
# 2014-11-01 00:00:00     0.41     0.27
# 2014-11-01 01:00:00     0.27     0.19
# 2014-11-01 02:00:00     0.19     0.12
# 2014-11-01 03:00:00     0.12     0.10
# 2014-11-01 04:00:00     0.10     0.10
#
# [5 rows x 24 columns]

# %% [markdown]
# Make predictions on the test data

# %%
# %%time
training_window = 720 # dedicate 30 days (720 hours) for training

train_ts = train['load']
test_ts = test_shifted

history = [x for x in train_ts]
history = history[(-training_window):]

predictions = list()

for t in range(test_ts.shape[0]):
    model = SARIMAX(endog=history, order=order, seasonal_order=seasonal_order)
    model_fit = model.fit()
    yhat = model_fit.forecast(steps = HORIZON)
    predictions.append(yhat)
    obs = list(test_ts.iloc[t])
    # move the training window
    history.append(obs[0])
    history.pop(0)
    print(t+1, '. Predicting time step: ', test_ts.index[t])
    # print(t+1, ': predicted =', yhat, 'expected =', obs)
# Out:
# 1 . Predicting time step:  2014-11-01 00:00:00
# 2 . Predicting time step:  2014-11-01 01:00:00
# 3 . Predicting time step:  2014-11-01 02:00:00
# 4 . Predicting time step:  2014-11-01 03:00:00
# 5 . Predicting time step:  2014-11-01 04:00:00
# 6 . Predicting time step:  2014-11-01 05:00:00
# 7 . Predicting time step:  2014-11-01 06:00:00
# 8 . Predicting time step:  2014-11-01 07:00:00
# 9 . Predicting time step:  2014-11-01 08:00:00
# 10 . Predicting time step:  2014-11-01 09:00:00
# 11 . Predicting time step:  2014-11-01 10:00:00
# 12 . Predicting time step:  2014-11-01 11:00:00
# 13 . Predicting time step:  2014-11-01 12:00:00
# 14 . Predicting time step:  2014-11-01 13:00:00
# 15 . Predicting time step:  2014-11-01 14:00:00
# 16 . Predicting time step:  2014-11-01 15:00:00
# 17 . Predicting time step:  2014-11-01 16:00:00
# 18 . Predicting time step:  2014-11-01 17:00:00
# 19 . Predicting time step:  2014-11-01 18:00:00
# 20 . Predicting time step:  2014-11-01 19:00:00
# 21 . Predicting time step:  2014-11-01 20:00:00
# 22 . Predicting time step:  2014-11-01 21:00:00
# 23 . Predicting time step:  2014-11-01 22:00:00
# 24 . Predicting time step:  2014-11-01 23:00:00
# 25 . Predicting time step:  2014-11-02 00:00:00
# 26 . Predicting time step:  2014-11-02 01:00:00
# 27 . Predicting time step:  2014-11-02 02:00:00
# 28 . Predicting time step:  2014-11-02 03:00:00
# 29 . Predicting time step:  2014-11-02 04:00:00
# 30 . Predicting time step:  2014-11-02 05:00:00
# 31 . Predicting time step:  2014-11-02 06:00:00
# 32 . Predicting time step:  2014-11-02 07:00:00
# 33 . Predicting time step:  2014-11-02 08:00:00
# 34 . Predicting time step:  2014-11-02 09:00:00
# 35 . Predicting time step:  2014-11-02 10:00:00
# 36 . Predicting time step:  2014-11-02 11:00:00
# 37 . Predicting time step:  2014-11-02 12:00:00
# 38 . Predicting time step:  2014-11-02 13:00:00
# 39 . Predicting time step:  2014-11-02 14:00:00
# 40 . Predicting time step:  2014-11-02 15:00:00
# 41 . Predicting time step:  2014-11-02 16:00:00
# 42 . Predicting time step:  2014-11-02 17:00:00
# 43 . Predicting time step:  2014-11-02 18:00:00
# 44 . Predicting time step:  2014-11-02 19:00:00
# 45 . Predicting time step:  2014-11-02 20:00:00
# 46 . Predicting time step:  2014-11-02 21:00:00
# 47 . Predicting time step:  2014-11-02 22:00:00
# 48 . Predicting time step:  2014-11-02 23:00:00
# 49 . Predicting time step:  2014-11-03 00:00:00
# 50 . Predicting time step:  2014-11-03 01:00:00
# 51 . Predicting time step:  2014-11-03 02:00:00
# 52 . Predicting time step:  2014-11-03 03:00:00
# 53 . Predicting time step:  2014-11-03 04:00:00
# 54 . Predicting time step:  2014-11-03 05:00:00
# 55 . Predicting time step:  2014-11-03 06:00:00
# 56 . Predicting time step:  2014-11-03 07:00:00
# 57 . Predicting time step:  2014-11-03 08:00:00
# 58 . Predicting time step:  2014-11-03 09:00:00
# 59 . Predicting time step:  2014-11-03 10:00:00
# 60 . Predicting time step:  2014-11-03 11:00:00
# 61 . Predicting time step:  2014-11-03 12:00:00
# 62 . Predicting time step:  2014-11-03 13:00:00
# 63 . Predicting time step:  2014-11-03 14:00:00
# 64 . Predicting time step:  2014-11-03 15:00:00
# 65 . Predicting time step:  2014-11-03 16:00:00
# 66 . Predicting time step:  2014-11-03 17:00:00
# 67 . Predicting time step:  2014-11-03 18:00:00
# 68 . Predicting time step:  2014-11-03 19:00:00
# 69 . Predicting time step:  2014-11-03 20:00:00
# 70 . Predicting time step:  2014-11-03 21:00:00
# 71 . Predicting time step:  2014-11-03 22:00:00
# 72 . Predicting time step:  2014-11-03 23:00:00
# 73 . Predicting time step:  2014-11-04 00:00:00
# 74 . Predicting time step:  2014-11-04 01:00:00
# 75 . Predicting time step:  2014-11-04 02:00:00
# 76 . Predicting time step:  2014-11-04 03:00:00
# 77 . Predicting time step:  2014-11-04 04:00:00
# 78 . Predicting time step:  2014-11-04 05:00:00
# 79 . Predicting time step:  2014-11-04 06:00:00
# 80 . Predicting time step:  2014-11-04 07:00:00
# 81 . Predicting time step:  2014-11-04 08:00:00
# 82 . Predicting time step:  2014-11-04 09:00:00
# 83 . Predicting time step:  2014-11-04 10:00:00
# 84 . Predicting time step:  2014-11-04 11:00:00
# 85 . Predicting time step:  2014-11-04 12:00:00
# 86 . Predicting time step:  2014-11-04 13:00:00
# 87 . Predicting time step:  2014-11-04 14:00:00
# 88 . Predicting time step:  2014-11-04 15:00:00
# 89 . Predicting time step:  2014-11-04 16:00:00
# 90 . Predicting time step:  2014-11-04 17:00:00
# 91 . Predicting time step:  2014-11-04 18:00:00
# 92 . Predicting time step:  2014-11-04 19:00:00
# 93 . Predicting time step:  2014-11-04 20:00:00
# 94 . Predicting time step:  2014-11-04 21:00:00
# 95 . Predicting time step:  2014-11-04 22:00:00
# 96 . Predicting time step:  2014-11-04 23:00:00
# 97 . Predicting time step:  2014-11-05 00:00:00
# 98 . Predicting time step:  2014-11-05 01:00:00
# 99 . Predicting time step:  2014-11-05 02:00:00
# 100 . Predicting time step:  2014-11-05 03:00:00
# 101 . Predicting time step:  2014-11-05 04:00:00
# 102 . Predicting time step:  2014-11-05 05:00:00
# 103 . Predicting time step:  2014-11-05 06:00:00
# 104 . Predicting time step:  2014-11-05 07:00:00
# 105 . Predicting time step:  2014-11-05 08:00:00
# 106 . Predicting time step:  2014-11-05 09:00:00
# 107 . Predicting time step:  2014-11-05 10:00:00
# 108 . Predicting time step:  2014-11-05 11:00:00
# 109 . Predicting time step:  2014-11-05 12:00:00
# 110 . Predicting time step:  2014-11-05 13:00:00
# 111 . Predicting time step:  2014-11-05 14:00:00
# 112 . Predicting time step:  2014-11-05 15:00:00
# 113 . Predicting time step:  2014-11-05 16:00:00
# 114 . Predicting time step:  2014-11-05 17:00:00
# 115 . Predicting time step:  2014-11-05 18:00:00
# 116 . Predicting time step:  2014-11-05 19:00:00
# 117 . Predicting time step:  2014-11-05 20:00:00
# 118 . Predicting time step:  2014-11-05 21:00:00
# 119 . Predicting time step:  2014-11-05 22:00:00
# 120 . Predicting time step:  2014-11-05 23:00:00
# 121 . Predicting time step:  2014-11-06 00:00:00
# 122 . Predicting time step:  2014-11-06 01:00:00
# 123 . Predicting time step:  2014-11-06 02:00:00
# 124 . Predicting time step:  2014-11-06 03:00:00
# 125 . Predicting time step:  2014-11-06 04:00:00
# 126 . Predicting time step:  2014-11-06 05:00:00
# 127 . Predicting time step:  2014-11-06 06:00:00
# 128 . Predicting time step:  2014-11-06 07:00:00
# 129 . Predicting time step:  2014-11-06 08:00:00
# 130 . Predicting time step:  2014-11-06 09:00:00
# 131 . Predicting time step:  2014-11-06 10:00:00
# 132 . Predicting time step:  2014-11-06 11:00:00
# 133 . Predicting time step:  2014-11-06 12:00:00
# 134 . Predicting time step:  2014-11-06 13:00:00
# 135 . Predicting time step:  2014-11-06 14:00:00
# 136 . Predicting time step:  2014-11-06 15:00:00
# 137 . Predicting time step:  2014-11-06 16:00:00
# 138 . Predicting time step:  2014-11-06 17:00:00
# 139 . Predicting time step:  2014-11-06 18:00:00
# 140 . Predicting time step:  2014-11-06 19:00:00
# 141 . Predicting time step:  2014-11-06 20:00:00
# 142 . Predicting time step:  2014-11-06 21:00:00
# 143 . Predicting time step:  2014-11-06 22:00:00
# 144 . Predicting time step:  2014-11-06 23:00:00
# 145 . Predicting time step:  2014-11-07 00:00:00
# 146 . Predicting time step:  2014-11-07 01:00:00
# 147 . Predicting time step:  2014-11-07 02:00:00
# 148 . Predicting time step:  2014-11-07 03:00:00
# 149 . Predicting time step:  2014-11-07 04:00:00
# 150 . Predicting time step:  2014-11-07 05:00:00
# 151 . Predicting time step:  2014-11-07 06:00:00
# 152 . Predicting time step:  2014-11-07 07:00:00
# 153 . Predicting time step:  2014-11-07 08:00:00
# 154 . Predicting time step:  2014-11-07 09:00:00
# 155 . Predicting time step:  2014-11-07 10:00:00
# 156 . Predicting time step:  2014-11-07 11:00:00
# 157 . Predicting time step:  2014-11-07 12:00:00
# 158 . Predicting time step:  2014-11-07 13:00:00
# 159 . Predicting time step:  2014-11-07 14:00:00
# 160 . Predicting time step:  2014-11-07 15:00:00
# 161 . Predicting time step:  2014-11-07 16:00:00
# 162 . Predicting time step:  2014-11-07 17:00:00
# 163 . Predicting time step:  2014-11-07 18:00:00
# 164 . Predicting time step:  2014-11-07 19:00:00
# 165 . Predicting time step:  2014-11-07 20:00:00
# 166 . Predicting time step:  2014-11-07 21:00:00
# 167 . Predicting time step:  2014-11-07 22:00:00
# 168 . Predicting time step:  2014-11-07 23:00:00
# 169 . Predicting time step:  2014-11-08 00:00:00
# 170 . Predicting time step:  2014-11-08 01:00:00
# 171 . Predicting time step:  2014-11-08 02:00:00
# 172 . Predicting time step:  2014-11-08 03:00:00
# 173 . Predicting time step:  2014-11-08 04:00:00
# 174 . Predicting time step:  2014-11-08 05:00:00
# 175 . Predicting time step:  2014-11-08 06:00:00
# 176 . Predicting time step:  2014-11-08 07:00:00
# 177 . Predicting time step:  2014-11-08 08:00:00
# 178 . Predicting time step:  2014-11-08 09:00:00
# 179 . Predicting time step:  2014-11-08 10:00:00
# 180 . Predicting time step:  2014-11-08 11:00:00
# 181 . Predicting time step:  2014-11-08 12:00:00
# 182 . Predicting time step:  2014-11-08 13:00:00
# 183 . Predicting time step:  2014-11-08 14:00:00
# 184 . Predicting time step:  2014-11-08 15:00:00
# 185 . Predicting time step:  2014-11-08 16:00:00
# 186 . Predicting time step:  2014-11-08 17:00:00
# 187 . Predicting time step:  2014-11-08 18:00:00
# 188 . Predicting time step:  2014-11-08 19:00:00
# 189 . Predicting time step:  2014-11-08 20:00:00
# 190 . Predicting time step:  2014-11-08 21:00:00
# 191 . Predicting time step:  2014-11-08 22:00:00
# 192 . Predicting time step:  2014-11-08 23:00:00
# 193 . Predicting time step:  2014-11-09 00:00:00
# 194 . Predicting time step:  2014-11-09 01:00:00
# 195 . Predicting time step:  2014-11-09 02:00:00
# 196 . Predicting time step:  2014-11-09 03:00:00
# 197 . Predicting time step:  2014-11-09 04:00:00
# 198 . Predicting time step:  2014-11-09 05:00:00
# 199 . Predicting time step:  2014-11-09 06:00:00
# 200 . Predicting time step:  2014-11-09 07:00:00
# 201 . Predicting time step:  2014-11-09 08:00:00
# 202 . Predicting time step:  2014-11-09 09:00:00
# 203 . Predicting time step:  2014-11-09 10:00:00
# 204 . Predicting time step:  2014-11-09 11:00:00
# 205 . Predicting time step:  2014-11-09 12:00:00
# 206 . Predicting time step:  2014-11-09 13:00:00
# 207 . Predicting time step:  2014-11-09 14:00:00
# 208 . Predicting time step:  2014-11-09 15:00:00
# 209 . Predicting time step:  2014-11-09 16:00:00
# 210 . Predicting time step:  2014-11-09 17:00:00
# 211 . Predicting time step:  2014-11-09 18:00:00
# 212 . Predicting time step:  2014-11-09 19:00:00
# 213 . Predicting time step:  2014-11-09 20:00:00
# 214 . Predicting time step:  2014-11-09 21:00:00
# 215 . Predicting time step:  2014-11-09 22:00:00
# 216 . Predicting time step:  2014-11-09 23:00:00
# 217 . Predicting time step:  2014-11-10 00:00:00
# 218 . Predicting time step:  2014-11-10 01:00:00
# 219 . Predicting time step:  2014-11-10 02:00:00
# 220 . Predicting time step:  2014-11-10 03:00:00
# 221 . Predicting time step:  2014-11-10 04:00:00
# 222 . Predicting time step:  2014-11-10 05:00:00
# 223 . Predicting time step:  2014-11-10 06:00:00
# 224 . Predicting time step:  2014-11-10 07:00:00
# 225 . Predicting time step:  2014-11-10 08:00:00
# 226 . Predicting time step:  2014-11-10 09:00:00
# 227 . Predicting time step:  2014-11-10 10:00:00
# 228 . Predicting time step:  2014-11-10 11:00:00
# 229 . Predicting time step:  2014-11-10 12:00:00
# 230 . Predicting time step:  2014-11-10 13:00:00
# 231 . Predicting time step:  2014-11-10 14:00:00
# 232 . Predicting time step:  2014-11-10 15:00:00
# 233 . Predicting time step:  2014-11-10 16:00:00
# 234 . Predicting time step:  2014-11-10 17:00:00
# 235 . Predicting time step:  2014-11-10 18:00:00
# 236 . Predicting time step:  2014-11-10 19:00:00
# 237 . Predicting time step:  2014-11-10 20:00:00
# 238 . Predicting time step:  2014-11-10 21:00:00
# 239 . Predicting time step:  2014-11-10 22:00:00
# 240 . Predicting time step:  2014-11-10 23:00:00
# 241 . Predicting time step:  2014-11-11 00:00:00
# 242 . Predicting time step:  2014-11-11 01:00:00
# 243 . Predicting time step:  2014-11-11 02:00:00
# 244 . Predicting time step:  2014-11-11 03:00:00
# 245 . Predicting time step:  2014-11-11 04:00:00
# 246 . Predicting time step:  2014-11-11 05:00:00
# 247 . Predicting time step:  2014-11-11 06:00:00
# 248 . Predicting time step:  2014-11-11 07:00:00
# 249 . Predicting time step:  2014-11-11 08:00:00
# 250 . Predicting time step:  2014-11-11 09:00:00
# 251 . Predicting time step:  2014-11-11 10:00:00
# 252 . Predicting time step:  2014-11-11 11:00:00
# 253 . Predicting time step:  2014-11-11 12:00:00
# 254 . Predicting time step:  2014-11-11 13:00:00
# 255 . Predicting time step:  2014-11-11 14:00:00
# 256 . Predicting time step:  2014-11-11 15:00:00
# 257 . Predicting time step:  2014-11-11 16:00:00
# 258 . Predicting time step:  2014-11-11 17:00:00
# 259 . Predicting time step:  2014-11-11 18:00:00
# 260 . Predicting time step:  2014-11-11 19:00:00
# 261 . Predicting time step:  2014-11-11 20:00:00
# 262 . Predicting time step:  2014-11-11 21:00:00
# 263 . Predicting time step:  2014-11-11 22:00:00
# 264 . Predicting time step:  2014-11-11 23:00:00
# 265 . Predicting time step:  2014-11-12 00:00:00
# 266 . Predicting time step:  2014-11-12 01:00:00
# 267 . Predicting time step:  2014-11-12 02:00:00
# 268 . Predicting time step:  2014-11-12 03:00:00
# 269 . Predicting time step:  2014-11-12 04:00:00
# 270 . Predicting time step:  2014-11-12 05:00:00
# 271 . Predicting time step:  2014-11-12 06:00:00
# 272 . Predicting time step:  2014-11-12 07:00:00
# 273 . Predicting time step:  2014-11-12 08:00:00
# 274 . Predicting time step:  2014-11-12 09:00:00
# 275 . Predicting time step:  2014-11-12 10:00:00
# 276 . Predicting time step:  2014-11-12 11:00:00
# 277 . Predicting time step:  2014-11-12 12:00:00
# 278 . Predicting time step:  2014-11-12 13:00:00
# 279 . Predicting time step:  2014-11-12 14:00:00
# 280 . Predicting time step:  2014-11-12 15:00:00
# 281 . Predicting time step:  2014-11-12 16:00:00
# 282 . Predicting time step:  2014-11-12 17:00:00
# 283 . Predicting time step:  2014-11-12 18:00:00
# 284 . Predicting time step:  2014-11-12 19:00:00
# 285 . Predicting time step:  2014-11-12 20:00:00
# 286 . Predicting time step:  2014-11-12 21:00:00
# 287 . Predicting time step:  2014-11-12 22:00:00
# 288 . Predicting time step:  2014-11-12 23:00:00
# 289 . Predicting time step:  2014-11-13 00:00:00
# 290 . Predicting time step:  2014-11-13 01:00:00
# 291 . Predicting time step:  2014-11-13 02:00:00
# 292 . Predicting time step:  2014-11-13 03:00:00
# 293 . Predicting time step:  2014-11-13 04:00:00
# 294 . Predicting time step:  2014-11-13 05:00:00
# 295 . Predicting time step:  2014-11-13 06:00:00
# 296 . Predicting time step:  2014-11-13 07:00:00
# 297 . Predicting time step:  2014-11-13 08:00:00
# 298 . Predicting time step:  2014-11-13 09:00:00
# 299 . Predicting time step:  2014-11-13 10:00:00
# 300 . Predicting time step:  2014-11-13 11:00:00
# 301 . Predicting time step:  2014-11-13 12:00:00
# 302 . Predicting time step:  2014-11-13 13:00:00
# 303 . Predicting time step:  2014-11-13 14:00:00
# 304 . Predicting time step:  2014-11-13 15:00:00
# 305 . Predicting time step:  2014-11-13 16:00:00
# 306 . Predicting time step:  2014-11-13 17:00:00
# 307 . Predicting time step:  2014-11-13 18:00:00
# 308 . Predicting time step:  2014-11-13 19:00:00
# 309 . Predicting time step:  2014-11-13 20:00:00
# 310 . Predicting time step:  2014-11-13 21:00:00
# 311 . Predicting time step:  2014-11-13 22:00:00
# 312 . Predicting time step:  2014-11-13 23:00:00
# 313 . Predicting time step:  2014-11-14 00:00:00
# 314 . Predicting time step:  2014-11-14 01:00:00
# 315 . Predicting time step:  2014-11-14 02:00:00
# 316 . Predicting time step:  2014-11-14 03:00:00
# 317 . Predicting time step:  2014-11-14 04:00:00
# 318 . Predicting time step:  2014-11-14 05:00:00
# 319 . Predicting time step:  2014-11-14 06:00:00
# 320 . Predicting time step:  2014-11-14 07:00:00
# 321 . Predicting time step:  2014-11-14 08:00:00
# 322 . Predicting time step:  2014-11-14 09:00:00
# 323 . Predicting time step:  2014-11-14 10:00:00
# 324 . Predicting time step:  2014-11-14 11:00:00
# 325 . Predicting time step:  2014-11-14 12:00:00
# 326 . Predicting time step:  2014-11-14 13:00:00
# 327 . Predicting time step:  2014-11-14 14:00:00
# 328 . Predicting time step:  2014-11-14 15:00:00
# 329 . Predicting time step:  2014-11-14 16:00:00
# 330 . Predicting time step:  2014-11-14 17:00:00
# 331 . Predicting time step:  2014-11-14 18:00:00
# 332 . Predicting time step:  2014-11-14 19:00:00
# 333 . Predicting time step:  2014-11-14 20:00:00
# 334 . Predicting time step:  2014-11-14 21:00:00
# 335 . Predicting time step:  2014-11-14 22:00:00
# 336 . Predicting time step:  2014-11-14 23:00:00
# 337 . Predicting time step:  2014-11-15 00:00:00
# 338 . Predicting time step:  2014-11-15 01:00:00
# 339 . Predicting time step:  2014-11-15 02:00:00
# 340 . Predicting time step:  2014-11-15 03:00:00
# 341 . Predicting time step:  2014-11-15 04:00:00
# 342 . Predicting time step:  2014-11-15 05:00:00
# 343 . Predicting time step:  2014-11-15 06:00:00
# 344 . Predicting time step:  2014-11-15 07:00:00
# 345 . Predicting time step:  2014-11-15 08:00:00
# 346 . Predicting time step:  2014-11-15 09:00:00
# 347 . Predicting time step:  2014-11-15 10:00:00
# 348 . Predicting time step:  2014-11-15 11:00:00
# 349 . Predicting time step:  2014-11-15 12:00:00
# 350 . Predicting time step:  2014-11-15 13:00:00
# 351 . Predicting time step:  2014-11-15 14:00:00
# 352 . Predicting time step:  2014-11-15 15:00:00
# 353 . Predicting time step:  2014-11-15 16:00:00
# 354 . Predicting time step:  2014-11-15 17:00:00
# 355 . Predicting time step:  2014-11-15 18:00:00
# 356 . Predicting time step:  2014-11-15 19:00:00
# 357 . Predicting time step:  2014-11-15 20:00:00
# 358 . Predicting time step:  2014-11-15 21:00:00
# 359 . Predicting time step:  2014-11-15 22:00:00
# 360 . Predicting time step:  2014-11-15 23:00:00
# 361 . Predicting time step:  2014-11-16 00:00:00
# 362 . Predicting time step:  2014-11-16 01:00:00
# 363 . Predicting time step:  2014-11-16 02:00:00
# 364 . Predicting time step:  2014-11-16 03:00:00
# 365 . Predicting time step:  2014-11-16 04:00:00
# 366 . Predicting time step:  2014-11-16 05:00:00
# 367 . Predicting time step:  2014-11-16 06:00:00
# 368 . Predicting time step:  2014-11-16 07:00:00
# 369 . Predicting time step:  2014-11-16 08:00:00
# 370 . Predicting time step:  2014-11-16 09:00:00
# 371 . Predicting time step:  2014-11-16 10:00:00
# 372 . Predicting time step:  2014-11-16 11:00:00
# 373 . Predicting time step:  2014-11-16 12:00:00
# 374 . Predicting time step:  2014-11-16 13:00:00
# 375 . Predicting time step:  2014-11-16 14:00:00
# 376 . Predicting time step:  2014-11-16 15:00:00
# 377 . Predicting time step:  2014-11-16 16:00:00
# 378 . Predicting time step:  2014-11-16 17:00:00
# 379 . Predicting time step:  2014-11-16 18:00:00
# 380 . Predicting time step:  2014-11-16 19:00:00
# 381 . Predicting time step:  2014-11-16 20:00:00
# 382 . Predicting time step:  2014-11-16 21:00:00
# 383 . Predicting time step:  2014-11-16 22:00:00
# 384 . Predicting time step:  2014-11-16 23:00:00
# 385 . Predicting time step:  2014-11-17 00:00:00
# 386 . Predicting time step:  2014-11-17 01:00:00
# 387 . Predicting time step:  2014-11-17 02:00:00
# 388 . Predicting time step:  2014-11-17 03:00:00
# 389 . Predicting time step:  2014-11-17 04:00:00
# 390 . Predicting time step:  2014-11-17 05:00:00
# 391 . Predicting time step:  2014-11-17 06:00:00
# 392 . Predicting time step:  2014-11-17 07:00:00
# 393 . Predicting time step:  2014-11-17 08:00:00
# 394 . Predicting time step:  2014-11-17 09:00:00
# 395 . Predicting time step:  2014-11-17 10:00:00
# 396 . Predicting time step:  2014-11-17 11:00:00
# 397 . Predicting time step:  2014-11-17 12:00:00
# 398 . Predicting time step:  2014-11-17 13:00:00
# 399 . Predicting time step:  2014-11-17 14:00:00
# 400 . Predicting time step:  2014-11-17 15:00:00
# 401 . Predicting time step:  2014-11-17 16:00:00
# 402 . Predicting time step:  2014-11-17 17:00:00
# 403 . Predicting time step:  2014-11-17 18:00:00
# 404 . Predicting time step:  2014-11-17 19:00:00
# 405 . Predicting time step:  2014-11-17 20:00:00
# 406 . Predicting time step:  2014-11-17 21:00:00
# 407 . Predicting time step:  2014-11-17 22:00:00
# 408 . Predicting time step:  2014-11-17 23:00:00
# 409 . Predicting time step:  2014-11-18 00:00:00
# 410 . Predicting time step:  2014-11-18 01:00:00
# 411 . Predicting time step:  2014-11-18 02:00:00
# 412 . Predicting time step:  2014-11-18 03:00:00
# 413 . Predicting time step:  2014-11-18 04:00:00
# 414 . Predicting time step:  2014-11-18 05:00:00
# 415 . Predicting time step:  2014-11-18 06:00:00
# 416 . Predicting time step:  2014-11-18 07:00:00
# 417 . Predicting time step:  2014-11-18 08:00:00
# 418 . Predicting time step:  2014-11-18 09:00:00
# 419 . Predicting time step:  2014-11-18 10:00:00
# 420 . Predicting time step:  2014-11-18 11:00:00
# 421 . Predicting time step:  2014-11-18 12:00:00
# 422 . Predicting time step:  2014-11-18 13:00:00
# 423 . Predicting time step:  2014-11-18 14:00:00
# 424 . Predicting time step:  2014-11-18 15:00:00
# 425 . Predicting time step:  2014-11-18 16:00:00
# 426 . Predicting time step:  2014-11-18 17:00:00
# 427 . Predicting time step:  2014-11-18 18:00:00
# 428 . Predicting time step:  2014-11-18 19:00:00
# 429 . Predicting time step:  2014-11-18 20:00:00
# 430 . Predicting time step:  2014-11-18 21:00:00
# 431 . Predicting time step:  2014-11-18 22:00:00
# 432 . Predicting time step:  2014-11-18 23:00:00
# 433 . Predicting time step:  2014-11-19 00:00:00
# 434 . Predicting time step:  2014-11-19 01:00:00
# 435 . Predicting time step:  2014-11-19 02:00:00
# 436 . Predicting time step:  2014-11-19 03:00:00
# 437 . Predicting time step:  2014-11-19 04:00:00
# 438 . Predicting time step:  2014-11-19 05:00:00
# 439 . Predicting time step:  2014-11-19 06:00:00
# 440 . Predicting time step:  2014-11-19 07:00:00
# 441 . Predicting time step:  2014-11-19 08:00:00
# 442 . Predicting time step:  2014-11-19 09:00:00
# 443 . Predicting time step:  2014-11-19 10:00:00
# 444 . Predicting time step:  2014-11-19 11:00:00
# 445 . Predicting time step:  2014-11-19 12:00:00
# 446 . Predicting time step:  2014-11-19 13:00:00
# 447 . Predicting time step:  2014-11-19 14:00:00
# 448 . Predicting time step:  2014-11-19 15:00:00
# 449 . Predicting time step:  2014-11-19 16:00:00
# 450 . Predicting time step:  2014-11-19 17:00:00
# 451 . Predicting time step:  2014-11-19 18:00:00
# 452 . Predicting time step:  2014-11-19 19:00:00
# 453 . Predicting time step:  2014-11-19 20:00:00
# 454 . Predicting time step:  2014-11-19 21:00:00
# 455 . Predicting time step:  2014-11-19 22:00:00
# 456 . Predicting time step:  2014-11-19 23:00:00
# 457 . Predicting time step:  2014-11-20 00:00:00
# 458 . Predicting time step:  2014-11-20 01:00:00
# 459 . Predicting time step:  2014-11-20 02:00:00
# 460 . Predicting time step:  2014-11-20 03:00:00
# 461 . Predicting time step:  2014-11-20 04:00:00
# 462 . Predicting time step:  2014-11-20 05:00:00
# 463 . Predicting time step:  2014-11-20 06:00:00
# 464 . Predicting time step:  2014-11-20 07:00:00
# 465 . Predicting time step:  2014-11-20 08:00:00
# 466 . Predicting time step:  2014-11-20 09:00:00
# 467 . Predicting time step:  2014-11-20 10:00:00
# 468 . Predicting time step:  2014-11-20 11:00:00
# 469 . Predicting time step:  2014-11-20 12:00:00
# 470 . Predicting time step:  2014-11-20 13:00:00
# 471 . Predicting time step:  2014-11-20 14:00:00
# 472 . Predicting time step:  2014-11-20 15:00:00
# 473 . Predicting time step:  2014-11-20 16:00:00
# 474 . Predicting time step:  2014-11-20 17:00:00
# 475 . Predicting time step:  2014-11-20 18:00:00
# 476 . Predicting time step:  2014-11-20 19:00:00
# 477 . Predicting time step:  2014-11-20 20:00:00
# 478 . Predicting time step:  2014-11-20 21:00:00
# 479 . Predicting time step:  2014-11-20 22:00:00
# 480 . Predicting time step:  2014-11-20 23:00:00
# 481 . Predicting time step:  2014-11-21 00:00:00
# 482 . Predicting time step:  2014-11-21 01:00:00
# 483 . Predicting time step:  2014-11-21 02:00:00
# 484 . Predicting time step:  2014-11-21 03:00:00
# 485 . Predicting time step:  2014-11-21 04:00:00
# 486 . Predicting time step:  2014-11-21 05:00:00
# 487 . Predicting time step:  2014-11-21 06:00:00
# 488 . Predicting time step:  2014-11-21 07:00:00
# 489 . Predicting time step:  2014-11-21 08:00:00
# 490 . Predicting time step:  2014-11-21 09:00:00
# 491 . Predicting time step:  2014-11-21 10:00:00
# 492 . Predicting time step:  2014-11-21 11:00:00
# 493 . Predicting time step:  2014-11-21 12:00:00
# 494 . Predicting time step:  2014-11-21 13:00:00
# 495 . Predicting time step:  2014-11-21 14:00:00
# 496 . Predicting time step:  2014-11-21 15:00:00
# 497 . Predicting time step:  2014-11-21 16:00:00
# 498 . Predicting time step:  2014-11-21 17:00:00
# 499 . Predicting time step:  2014-11-21 18:00:00
# 500 . Predicting time step:  2014-11-21 19:00:00
# 501 . Predicting time step:  2014-11-21 20:00:00
# 502 . Predicting time step:  2014-11-21 21:00:00
# 503 . Predicting time step:  2014-11-21 22:00:00
# 504 . Predicting time step:  2014-11-21 23:00:00
# 505 . Predicting time step:  2014-11-22 00:00:00
# 506 . Predicting time step:  2014-11-22 01:00:00
# 507 . Predicting time step:  2014-11-22 02:00:00
# 508 . Predicting time step:  2014-11-22 03:00:00
# 509 . Predicting time step:  2014-11-22 04:00:00
# 510 . Predicting time step:  2014-11-22 05:00:00
# 511 . Predicting time step:  2014-11-22 06:00:00
# 512 . Predicting time step:  2014-11-22 07:00:00
# 513 . Predicting time step:  2014-11-22 08:00:00
# 514 . Predicting time step:  2014-11-22 09:00:00
# 515 . Predicting time step:  2014-11-22 10:00:00
# 516 . Predicting time step:  2014-11-22 11:00:00
# 517 . Predicting time step:  2014-11-22 12:00:00
# 518 . Predicting time step:  2014-11-22 13:00:00
# 519 . Predicting time step:  2014-11-22 14:00:00
# 520 . Predicting time step:  2014-11-22 15:00:00
# 521 . Predicting time step:  2014-11-22 16:00:00
# 522 . Predicting time step:  2014-11-22 17:00:00
# 523 . Predicting time step:  2014-11-22 18:00:00
# 524 . Predicting time step:  2014-11-22 19:00:00
# 525 . Predicting time step:  2014-11-22 20:00:00
# 526 . Predicting time step:  2014-11-22 21:00:00
# 527 . Predicting time step:  2014-11-22 22:00:00
# 528 . Predicting time step:  2014-11-22 23:00:00
# 529 . Predicting time step:  2014-11-23 00:00:00
# 530 . Predicting time step:  2014-11-23 01:00:00
# 531 . Predicting time step:  2014-11-23 02:00:00
# 532 . Predicting time step:  2014-11-23 03:00:00
# 533 . Predicting time step:  2014-11-23 04:00:00
# 534 . Predicting time step:  2014-11-23 05:00:00
# 535 . Predicting time step:  2014-11-23 06:00:00
# 536 . Predicting time step:  2014-11-23 07:00:00
# 537 . Predicting time step:  2014-11-23 08:00:00
# 538 . Predicting time step:  2014-11-23 09:00:00
# 539 . Predicting time step:  2014-11-23 10:00:00
# 540 . Predicting time step:  2014-11-23 11:00:00
# 541 . Predicting time step:  2014-11-23 12:00:00
# 542 . Predicting time step:  2014-11-23 13:00:00
# 543 . Predicting time step:  2014-11-23 14:00:00
# 544 . Predicting time step:  2014-11-23 15:00:00
# 545 . Predicting time step:  2014-11-23 16:00:00
# 546 . Predicting time step:  2014-11-23 17:00:00
# 547 . Predicting time step:  2014-11-23 18:00:00
# 548 . Predicting time step:  2014-11-23 19:00:00
# 549 . Predicting time step:  2014-11-23 20:00:00
# 550 . Predicting time step:  2014-11-23 21:00:00
# 551 . Predicting time step:  2014-11-23 22:00:00
# 552 . Predicting time step:  2014-11-23 23:00:00
# 553 . Predicting time step:  2014-11-24 00:00:00
# 554 . Predicting time step:  2014-11-24 01:00:00
# 555 . Predicting time step:  2014-11-24 02:00:00
# 556 . Predicting time step:  2014-11-24 03:00:00
# 557 . Predicting time step:  2014-11-24 04:00:00
# 558 . Predicting time step:  2014-11-24 05:00:00
# 559 . Predicting time step:  2014-11-24 06:00:00
# 560 . Predicting time step:  2014-11-24 07:00:00
# 561 . Predicting time step:  2014-11-24 08:00:00
# 562 . Predicting time step:  2014-11-24 09:00:00
# 563 . Predicting time step:  2014-11-24 10:00:00
# 564 . Predicting time step:  2014-11-24 11:00:00
# 565 . Predicting time step:  2014-11-24 12:00:00
# 566 . Predicting time step:  2014-11-24 13:00:00
# 567 . Predicting time step:  2014-11-24 14:00:00
# 568 . Predicting time step:  2014-11-24 15:00:00
# 569 . Predicting time step:  2014-11-24 16:00:00
# 570 . Predicting time step:  2014-11-24 17:00:00
# 571 . Predicting time step:  2014-11-24 18:00:00
# 572 . Predicting time step:  2014-11-24 19:00:00
# 573 . Predicting time step:  2014-11-24 20:00:00
# 574 . Predicting time step:  2014-11-24 21:00:00
# 575 . Predicting time step:  2014-11-24 22:00:00
# 576 . Predicting time step:  2014-11-24 23:00:00
# 577 . Predicting time step:  2014-11-25 00:00:00
# 578 . Predicting time step:  2014-11-25 01:00:00
# 579 . Predicting time step:  2014-11-25 02:00:00
# 580 . Predicting time step:  2014-11-25 03:00:00
# 581 . Predicting time step:  2014-11-25 04:00:00
# 582 . Predicting time step:  2014-11-25 05:00:00
# 583 . Predicting time step:  2014-11-25 06:00:00
# 584 . Predicting time step:  2014-11-25 07:00:00
# 585 . Predicting time step:  2014-11-25 08:00:00
# 586 . Predicting time step:  2014-11-25 09:00:00
# 587 . Predicting time step:  2014-11-25 10:00:00
# 588 . Predicting time step:  2014-11-25 11:00:00
# 589 . Predicting time step:  2014-11-25 12:00:00
# 590 . Predicting time step:  2014-11-25 13:00:00
# 591 . Predicting time step:  2014-11-25 14:00:00
# 592 . Predicting time step:  2014-11-25 15:00:00
# 593 . Predicting time step:  2014-11-25 16:00:00
# 594 . Predicting time step:  2014-11-25 17:00:00
# 595 . Predicting time step:  2014-11-25 18:00:00
# 596 . Predicting time step:  2014-11-25 19:00:00
# 597 . Predicting time step:  2014-11-25 20:00:00
# 598 . Predicting time step:  2014-11-25 21:00:00
# 599 . Predicting time step:  2014-11-25 22:00:00
# 600 . Predicting time step:  2014-11-25 23:00:00
# 601 . Predicting time step:  2014-11-26 00:00:00
# 602 . Predicting time step:  2014-11-26 01:00:00
# 603 . Predicting time step:  2014-11-26 02:00:00
# 604 . Predicting time step:  2014-11-26 03:00:00
# 605 . Predicting time step:  2014-11-26 04:00:00
# 606 . Predicting time step:  2014-11-26 05:00:00
# 607 . Predicting time step:  2014-11-26 06:00:00
# 608 . Predicting time step:  2014-11-26 07:00:00
# 609 . Predicting time step:  2014-11-26 08:00:00
# 610 . Predicting time step:  2014-11-26 09:00:00
# 611 . Predicting time step:  2014-11-26 10:00:00
# 612 . Predicting time step:  2014-11-26 11:00:00
# 613 . Predicting time step:  2014-11-26 12:00:00
# 614 . Predicting time step:  2014-11-26 13:00:00
# 615 . Predicting time step:  2014-11-26 14:00:00
# 616 . Predicting time step:  2014-11-26 15:00:00
# 617 . Predicting time step:  2014-11-26 16:00:00
# 618 . Predicting time step:  2014-11-26 17:00:00
# 619 . Predicting time step:  2014-11-26 18:00:00
# 620 . Predicting time step:  2014-11-26 19:00:00
# 621 . Predicting time step:  2014-11-26 20:00:00
# 622 . Predicting time step:  2014-11-26 21:00:00
# 623 . Predicting time step:  2014-11-26 22:00:00
# 624 . Predicting time step:  2014-11-26 23:00:00
# 625 . Predicting time step:  2014-11-27 00:00:00
# 626 . Predicting time step:  2014-11-27 01:00:00
# 627 . Predicting time step:  2014-11-27 02:00:00
# 628 . Predicting time step:  2014-11-27 03:00:00
# 629 . Predicting time step:  2014-11-27 04:00:00
# 630 . Predicting time step:  2014-11-27 05:00:00
# 631 . Predicting time step:  2014-11-27 06:00:00
# 632 . Predicting time step:  2014-11-27 07:00:00
# 633 . Predicting time step:  2014-11-27 08:00:00
# 634 . Predicting time step:  2014-11-27 09:00:00
# 635 . Predicting time step:  2014-11-27 10:00:00
# 636 . Predicting time step:  2014-11-27 11:00:00
# 637 . Predicting time step:  2014-11-27 12:00:00
# 638 . Predicting time step:  2014-11-27 13:00:00
# 639 . Predicting time step:  2014-11-27 14:00:00
# 640 . Predicting time step:  2014-11-27 15:00:00
# 641 . Predicting time step:  2014-11-27 16:00:00
# 642 . Predicting time step:  2014-11-27 17:00:00
# 643 . Predicting time step:  2014-11-27 18:00:00
# 644 . Predicting time step:  2014-11-27 19:00:00
# 645 . Predicting time step:  2014-11-27 20:00:00
# 646 . Predicting time step:  2014-11-27 21:00:00
# 647 . Predicting time step:  2014-11-27 22:00:00
# 648 . Predicting time step:  2014-11-27 23:00:00
# 649 . Predicting time step:  2014-11-28 00:00:00
# 650 . Predicting time step:  2014-11-28 01:00:00
# 651 . Predicting time step:  2014-11-28 02:00:00
# 652 . Predicting time step:  2014-11-28 03:00:00
# 653 . Predicting time step:  2014-11-28 04:00:00
# 654 . Predicting time step:  2014-11-28 05:00:00
# 655 . Predicting time step:  2014-11-28 06:00:00
# 656 . Predicting time step:  2014-11-28 07:00:00
# 657 . Predicting time step:  2014-11-28 08:00:00
# 658 . Predicting time step:  2014-11-28 09:00:00
# 659 . Predicting time step:  2014-11-28 10:00:00
# 660 . Predicting time step:  2014-11-28 11:00:00
# 661 . Predicting time step:  2014-11-28 12:00:00
# 662 . Predicting time step:  2014-11-28 13:00:00
# 663 . Predicting time step:  2014-11-28 14:00:00
# 664 . Predicting time step:  2014-11-28 15:00:00
# 665 . Predicting time step:  2014-11-28 16:00:00
# 666 . Predicting time step:  2014-11-28 17:00:00
# 667 . Predicting time step:  2014-11-28 18:00:00
# 668 . Predicting time step:  2014-11-28 19:00:00
# 669 . Predicting time step:  2014-11-28 20:00:00
# 670 . Predicting time step:  2014-11-28 21:00:00
# 671 . Predicting time step:  2014-11-28 22:00:00
# 672 . Predicting time step:  2014-11-28 23:00:00
# 673 . Predicting time step:  2014-11-29 00:00:00
# 674 . Predicting time step:  2014-11-29 01:00:00
# 675 . Predicting time step:  2014-11-29 02:00:00
# 676 . Predicting time step:  2014-11-29 03:00:00
# 677 . Predicting time step:  2014-11-29 04:00:00
# 678 . Predicting time step:  2014-11-29 05:00:00
# 679 . Predicting time step:  2014-11-29 06:00:00
# 680 . Predicting time step:  2014-11-29 07:00:00
# 681 . Predicting time step:  2014-11-29 08:00:00
# 682 . Predicting time step:  2014-11-29 09:00:00
# 683 . Predicting time step:  2014-11-29 10:00:00
# 684 . Predicting time step:  2014-11-29 11:00:00
# 685 . Predicting time step:  2014-11-29 12:00:00
# 686 . Predicting time step:  2014-11-29 13:00:00
# 687 . Predicting time step:  2014-11-29 14:00:00
# 688 . Predicting time step:  2014-11-29 15:00:00
# 689 . Predicting time step:  2014-11-29 16:00:00
# 690 . Predicting time step:  2014-11-29 17:00:00
# 691 . Predicting time step:  2014-11-29 18:00:00
# 692 . Predicting time step:  2014-11-29 19:00:00
# 693 . Predicting time step:  2014-11-29 20:00:00
# 694 . Predicting time step:  2014-11-29 21:00:00
# 695 . Predicting time step:  2014-11-29 22:00:00
# 696 . Predicting time step:  2014-11-29 23:00:00
# 697 . Predicting time step:  2014-11-30 00:00:00
# 698 . Predicting time step:  2014-11-30 01:00:00
# 699 . Predicting time step:  2014-11-30 02:00:00
# 700 . Predicting time step:  2014-11-30 03:00:00
# 701 . Predicting time step:  2014-11-30 04:00:00
# 702 . Predicting time step:  2014-11-30 05:00:00
# 703 . Predicting time step:  2014-11-30 06:00:00
# 704 . Predicting time step:  2014-11-30 07:00:00
# 705 . Predicting time step:  2014-11-30 08:00:00
# 706 . Predicting time step:  2014-11-30 09:00:00
# 707 . Predicting time step:  2014-11-30 10:00:00
# 708 . Predicting time step:  2014-11-30 11:00:00
# 709 . Predicting time step:  2014-11-30 12:00:00
# 710 . Predicting time step:  2014-11-30 13:00:00
# 711 . Predicting time step:  2014-11-30 14:00:00
# 712 . Predicting time step:  2014-11-30 15:00:00
# 713 . Predicting time step:  2014-11-30 16:00:00
# 714 . Predicting time step:  2014-11-30 17:00:00
# 715 . Predicting time step:  2014-11-30 18:00:00
# 716 . Predicting time step:  2014-11-30 19:00:00
# 717 . Predicting time step:  2014-11-30 20:00:00
# 718 . Predicting time step:  2014-11-30 21:00:00
# 719 . Predicting time step:  2014-11-30 22:00:00
# 720 . Predicting time step:  2014-11-30 23:00:00
# 721 . Predicting time step:  2014-12-01 00:00:00
# 722 . Predicting time step:  2014-12-01 01:00:00
# 723 . Predicting time step:  2014-12-01 02:00:00
# 724 . Predicting time step:  2014-12-01 03:00:00
# 725 . Predicting time step:  2014-12-01 04:00:00
# 726 . Predicting time step:  2014-12-01 05:00:00
# 727 . Predicting time step:  2014-12-01 06:00:00
# 728 . Predicting time step:  2014-12-01 07:00:00
# 729 . Predicting time step:  2014-12-01 08:00:00
# 730 . Predicting time step:  2014-12-01 09:00:00
# 731 . Predicting time step:  2014-12-01 10:00:00
# 732 . Predicting time step:  2014-12-01 11:00:00
# 733 . Predicting time step:  2014-12-01 12:00:00
# 734 . Predicting time step:  2014-12-01 13:00:00
# 735 . Predicting time step:  2014-12-01 14:00:00
# 736 . Predicting time step:  2014-12-01 15:00:00
# 737 . Predicting time step:  2014-12-01 16:00:00
# 738 . Predicting time step:  2014-12-01 17:00:00
# 739 . Predicting time step:  2014-12-01 18:00:00
# 740 . Predicting time step:  2014-12-01 19:00:00
# 741 . Predicting time step:  2014-12-01 20:00:00
# 742 . Predicting time step:  2014-12-01 21:00:00
# 743 . Predicting time step:  2014-12-01 22:00:00
# 744 . Predicting time step:  2014-12-01 23:00:00
# 745 . Predicting time step:  2014-12-02 00:00:00
# 746 . Predicting time step:  2014-12-02 01:00:00
# 747 . Predicting time step:  2014-12-02 02:00:00
# 748 . Predicting time step:  2014-12-02 03:00:00
# 749 . Predicting time step:  2014-12-02 04:00:00
# 750 . Predicting time step:  2014-12-02 05:00:00
# 751 . Predicting time step:  2014-12-02 06:00:00
# 752 . Predicting time step:  2014-12-02 07:00:00
# 753 . Predicting time step:  2014-12-02 08:00:00
# 754 . Predicting time step:  2014-12-02 09:00:00
# 755 . Predicting time step:  2014-12-02 10:00:00
# 756 . Predicting time step:  2014-12-02 11:00:00
# 757 . Predicting time step:  2014-12-02 12:00:00
# 758 . Predicting time step:  2014-12-02 13:00:00
# 759 . Predicting time step:  2014-12-02 14:00:00
# 760 . Predicting time step:  2014-12-02 15:00:00
# 761 . Predicting time step:  2014-12-02 16:00:00
# 762 . Predicting time step:  2014-12-02 17:00:00
# 763 . Predicting time step:  2014-12-02 18:00:00
# 764 . Predicting time step:  2014-12-02 19:00:00
# 765 . Predicting time step:  2014-12-02 20:00:00
# 766 . Predicting time step:  2014-12-02 21:00:00
# 767 . Predicting time step:  2014-12-02 22:00:00
# 768 . Predicting time step:  2014-12-02 23:00:00
# 769 . Predicting time step:  2014-12-03 00:00:00
# 770 . Predicting time step:  2014-12-03 01:00:00
# 771 . Predicting time step:  2014-12-03 02:00:00
# 772 . Predicting time step:  2014-12-03 03:00:00
# 773 . Predicting time step:  2014-12-03 04:00:00
# 774 . Predicting time step:  2014-12-03 05:00:00
# 775 . Predicting time step:  2014-12-03 06:00:00
# 776 . Predicting time step:  2014-12-03 07:00:00
# 777 . Predicting time step:  2014-12-03 08:00:00
# 778 . Predicting time step:  2014-12-03 09:00:00
# 779 . Predicting time step:  2014-12-03 10:00:00
# 780 . Predicting time step:  2014-12-03 11:00:00
# 781 . Predicting time step:  2014-12-03 12:00:00
# 782 . Predicting time step:  2014-12-03 13:00:00
# 783 . Predicting time step:  2014-12-03 14:00:00
# 784 . Predicting time step:  2014-12-03 15:00:00
# 785 . Predicting time step:  2014-12-03 16:00:00
# 786 . Predicting time step:  2014-12-03 17:00:00
# 787 . Predicting time step:  2014-12-03 18:00:00
# 788 . Predicting time step:  2014-12-03 19:00:00
# 789 . Predicting time step:  2014-12-03 20:00:00
# 790 . Predicting time step:  2014-12-03 21:00:00
# 791 . Predicting time step:  2014-12-03 22:00:00
# 792 . Predicting time step:  2014-12-03 23:00:00
# 793 . Predicting time step:  2014-12-04 00:00:00
# 794 . Predicting time step:  2014-12-04 01:00:00
# 795 . Predicting time step:  2014-12-04 02:00:00
# 796 . Predicting time step:  2014-12-04 03:00:00
# 797 . Predicting time step:  2014-12-04 04:00:00
# 798 . Predicting time step:  2014-12-04 05:00:00
# 799 . Predicting time step:  2014-12-04 06:00:00
# 800 . Predicting time step:  2014-12-04 07:00:00
# 801 . Predicting time step:  2014-12-04 08:00:00
# 802 . Predicting time step:  2014-12-04 09:00:00
# 803 . Predicting time step:  2014-12-04 10:00:00
# 804 . Predicting time step:  2014-12-04 11:00:00
# 805 . Predicting time step:  2014-12-04 12:00:00
# 806 . Predicting time step:  2014-12-04 13:00:00
# 807 . Predicting time step:  2014-12-04 14:00:00
# 808 . Predicting time step:  2014-12-04 15:00:00
# 809 . Predicting time step:  2014-12-04 16:00:00
# 810 . Predicting time step:  2014-12-04 17:00:00
# 811 . Predicting time step:  2014-12-04 18:00:00
# 812 . Predicting time step:  2014-12-04 19:00:00
# 813 . Predicting time step:  2014-12-04 20:00:00
# 814 . Predicting time step:  2014-12-04 21:00:00
# 815 . Predicting time step:  2014-12-04 22:00:00
# 816 . Predicting time step:  2014-12-04 23:00:00
# 817 . Predicting time step:  2014-12-05 00:00:00
# 818 . Predicting time step:  2014-12-05 01:00:00
# 819 . Predicting time step:  2014-12-05 02:00:00
# 820 . Predicting time step:  2014-12-05 03:00:00
# 821 . Predicting time step:  2014-12-05 04:00:00
# 822 . Predicting time step:  2014-12-05 05:00:00
# 823 . Predicting time step:  2014-12-05 06:00:00
# 824 . Predicting time step:  2014-12-05 07:00:00
# 825 . Predicting time step:  2014-12-05 08:00:00
# 826 . Predicting time step:  2014-12-05 09:00:00
# 827 . Predicting time step:  2014-12-05 10:00:00
# 828 . Predicting time step:  2014-12-05 11:00:00
# 829 . Predicting time step:  2014-12-05 12:00:00
# 830 . Predicting time step:  2014-12-05 13:00:00
# 831 . Predicting time step:  2014-12-05 14:00:00
# 832 . Predicting time step:  2014-12-05 15:00:00
# 833 . Predicting time step:  2014-12-05 16:00:00
# 834 . Predicting time step:  2014-12-05 17:00:00
# 835 . Predicting time step:  2014-12-05 18:00:00
# 836 . Predicting time step:  2014-12-05 19:00:00
# 837 . Predicting time step:  2014-12-05 20:00:00
# 838 . Predicting time step:  2014-12-05 21:00:00
# 839 . Predicting time step:  2014-12-05 22:00:00
# 840 . Predicting time step:  2014-12-05 23:00:00
# 841 . Predicting time step:  2014-12-06 00:00:00
# 842 . Predicting time step:  2014-12-06 01:00:00
# 843 . Predicting time step:  2014-12-06 02:00:00
# 844 . Predicting time step:  2014-12-06 03:00:00
# 845 . Predicting time step:  2014-12-06 04:00:00
# 846 . Predicting time step:  2014-12-06 05:00:00
# 847 . Predicting time step:  2014-12-06 06:00:00
# 848 . Predicting time step:  2014-12-06 07:00:00
# 849 . Predicting time step:  2014-12-06 08:00:00
# 850 . Predicting time step:  2014-12-06 09:00:00
# 851 . Predicting time step:  2014-12-06 10:00:00
# 852 . Predicting time step:  2014-12-06 11:00:00
# 853 . Predicting time step:  2014-12-06 12:00:00
# 854 . Predicting time step:  2014-12-06 13:00:00
# 855 . Predicting time step:  2014-12-06 14:00:00
# 856 . Predicting time step:  2014-12-06 15:00:00
# 857 . Predicting time step:  2014-12-06 16:00:00
# 858 . Predicting time step:  2014-12-06 17:00:00
# 859 . Predicting time step:  2014-12-06 18:00:00
# 860 . Predicting time step:  2014-12-06 19:00:00
# 861 . Predicting time step:  2014-12-06 20:00:00
# 862 . Predicting time step:  2014-12-06 21:00:00
# 863 . Predicting time step:  2014-12-06 22:00:00
# 864 . Predicting time step:  2014-12-06 23:00:00
# 865 . Predicting time step:  2014-12-07 00:00:00
# 866 . Predicting time step:  2014-12-07 01:00:00
# 867 . Predicting time step:  2014-12-07 02:00:00
# 868 . Predicting time step:  2014-12-07 03:00:00
# 869 . Predicting time step:  2014-12-07 04:00:00
# 870 . Predicting time step:  2014-12-07 05:00:00
# 871 . Predicting time step:  2014-12-07 06:00:00
# 872 . Predicting time step:  2014-12-07 07:00:00
# 873 . Predicting time step:  2014-12-07 08:00:00
# 874 . Predicting time step:  2014-12-07 09:00:00
# 875 . Predicting time step:  2014-12-07 10:00:00
# 876 . Predicting time step:  2014-12-07 11:00:00
# 877 . Predicting time step:  2014-12-07 12:00:00
# 878 . Predicting time step:  2014-12-07 13:00:00
# 879 . Predicting time step:  2014-12-07 14:00:00
# 880 . Predicting time step:  2014-12-07 15:00:00
# 881 . Predicting time step:  2014-12-07 16:00:00
# 882 . Predicting time step:  2014-12-07 17:00:00
# 883 . Predicting time step:  2014-12-07 18:00:00
# 884 . Predicting time step:  2014-12-07 19:00:00
# 885 . Predicting time step:  2014-12-07 20:00:00
# 886 . Predicting time step:  2014-12-07 21:00:00
# 887 . Predicting time step:  2014-12-07 22:00:00
# 888 . Predicting time step:  2014-12-07 23:00:00
# 889 . Predicting time step:  2014-12-08 00:00:00
# 890 . Predicting time step:  2014-12-08 01:00:00
# 891 . Predicting time step:  2014-12-08 02:00:00
# 892 . Predicting time step:  2014-12-08 03:00:00
# 893 . Predicting time step:  2014-12-08 04:00:00
# 894 . Predicting time step:  2014-12-08 05:00:00
# 895 . Predicting time step:  2014-12-08 06:00:00
# 896 . Predicting time step:  2014-12-08 07:00:00
# 897 . Predicting time step:  2014-12-08 08:00:00
# 898 . Predicting time step:  2014-12-08 09:00:00
# 899 . Predicting time step:  2014-12-08 10:00:00
# 900 . Predicting time step:  2014-12-08 11:00:00
# 901 . Predicting time step:  2014-12-08 12:00:00
# 902 . Predicting time step:  2014-12-08 13:00:00
# 903 . Predicting time step:  2014-12-08 14:00:00
# 904 . Predicting time step:  2014-12-08 15:00:00
# 905 . Predicting time step:  2014-12-08 16:00:00
# 906 . Predicting time step:  2014-12-08 17:00:00
# 907 . Predicting time step:  2014-12-08 18:00:00
# 908 . Predicting time step:  2014-12-08 19:00:00
# 909 . Predicting time step:  2014-12-08 20:00:00
# 910 . Predicting time step:  2014-12-08 21:00:00
# 911 . Predicting time step:  2014-12-08 22:00:00
# 912 . Predicting time step:  2014-12-08 23:00:00
# 913 . Predicting time step:  2014-12-09 00:00:00
# 914 . Predicting time step:  2014-12-09 01:00:00
# 915 . Predicting time step:  2014-12-09 02:00:00
# 916 . Predicting time step:  2014-12-09 03:00:00
# 917 . Predicting time step:  2014-12-09 04:00:00
# 918 . Predicting time step:  2014-12-09 05:00:00
# 919 . Predicting time step:  2014-12-09 06:00:00
# 920 . Predicting time step:  2014-12-09 07:00:00
# 921 . Predicting time step:  2014-12-09 08:00:00
# 922 . Predicting time step:  2014-12-09 09:00:00
# 923 . Predicting time step:  2014-12-09 10:00:00
# 924 . Predicting time step:  2014-12-09 11:00:00
# 925 . Predicting time step:  2014-12-09 12:00:00
# 926 . Predicting time step:  2014-12-09 13:00:00
# 927 . Predicting time step:  2014-12-09 14:00:00
# 928 . Predicting time step:  2014-12-09 15:00:00
# 929 . Predicting time step:  2014-12-09 16:00:00
# 930 . Predicting time step:  2014-12-09 17:00:00
# 931 . Predicting time step:  2014-12-09 18:00:00
# 932 . Predicting time step:  2014-12-09 19:00:00
# 933 . Predicting time step:  2014-12-09 20:00:00
# 934 . Predicting time step:  2014-12-09 21:00:00
# 935 . Predicting time step:  2014-12-09 22:00:00
# 936 . Predicting time step:  2014-12-09 23:00:00
# 937 . Predicting time step:  2014-12-10 00:00:00
# 938 . Predicting time step:  2014-12-10 01:00:00
# 939 . Predicting time step:  2014-12-10 02:00:00
# 940 . Predicting time step:  2014-12-10 03:00:00
# 941 . Predicting time step:  2014-12-10 04:00:00
# 942 . Predicting time step:  2014-12-10 05:00:00
# 943 . Predicting time step:  2014-12-10 06:00:00
# 944 . Predicting time step:  2014-12-10 07:00:00
# 945 . Predicting time step:  2014-12-10 08:00:00
# 946 . Predicting time step:  2014-12-10 09:00:00
# 947 . Predicting time step:  2014-12-10 10:00:00
# 948 . Predicting time step:  2014-12-10 11:00:00
# 949 . Predicting time step:  2014-12-10 12:00:00
# 950 . Predicting time step:  2014-12-10 13:00:00
# 951 . Predicting time step:  2014-12-10 14:00:00
# 952 . Predicting time step:  2014-12-10 15:00:00
# 953 . Predicting time step:  2014-12-10 16:00:00
# 954 . Predicting time step:  2014-12-10 17:00:00
# 955 . Predicting time step:  2014-12-10 18:00:00
# 956 . Predicting time step:  2014-12-10 19:00:00
# 957 . Predicting time step:  2014-12-10 20:00:00
# 958 . Predicting time step:  2014-12-10 21:00:00
# 959 . Predicting time step:  2014-12-10 22:00:00
# 960 . Predicting time step:  2014-12-10 23:00:00
# 961 . Predicting time step:  2014-12-11 00:00:00
# 962 . Predicting time step:  2014-12-11 01:00:00
# 963 . Predicting time step:  2014-12-11 02:00:00
# 964 . Predicting time step:  2014-12-11 03:00:00
# 965 . Predicting time step:  2014-12-11 04:00:00
# 966 . Predicting time step:  2014-12-11 05:00:00
# 967 . Predicting time step:  2014-12-11 06:00:00
# 968 . Predicting time step:  2014-12-11 07:00:00
# 969 . Predicting time step:  2014-12-11 08:00:00
# 970 . Predicting time step:  2014-12-11 09:00:00
# 971 . Predicting time step:  2014-12-11 10:00:00
# 972 . Predicting time step:  2014-12-11 11:00:00
# 973 . Predicting time step:  2014-12-11 12:00:00
# 974 . Predicting time step:  2014-12-11 13:00:00
# 975 . Predicting time step:  2014-12-11 14:00:00
# 976 . Predicting time step:  2014-12-11 15:00:00
# 977 . Predicting time step:  2014-12-11 16:00:00
# 978 . Predicting time step:  2014-12-11 17:00:00
# 979 . Predicting time step:  2014-12-11 18:00:00
# 980 . Predicting time step:  2014-12-11 19:00:00
# 981 . Predicting time step:  2014-12-11 20:00:00
# ...
# 1124 . Predicting time step:  2014-12-17 19:00:00
# 1125 . Predicting time step:  2014-12-17 20:00:00
# 1126 . Predicting time step:  2014-12-17 21:00:00
# 1127 . Predicting time step:  2014-12-17 22:00:00
# 1128 . Predicting time step:  2014-12-17 23:00:00
# 1129 . Predicting time step:  2014-12-18 00:00:00
# 1130 . Predicting time step:  2014-12-18 01:00:00
# 1131 . Predicting time step:  2014-12-18 02:00:00
# 1132 . Predicting time step:  2014-12-18 03:00:00
# 1133 . Predicting time step:  2014-12-18 04:00:00
# 1134 . Predicting time step:  2014-12-18 05:00:00
# 1135 . Predicting time step:  2014-12-18 06:00:00
# 1136 . Predicting time step:  2014-12-18 07:00:00
# 1137 . Predicting time step:  2014-12-18 08:00:00
# 1138 . Predicting time step:  2014-12-18 09:00:00
# 1139 . Predicting time step:  2014-12-18 10:00:00
# 1140 . Predicting time step:  2014-12-18 11:00:00
# 1141 . Predicting time step:  2014-12-18 12:00:00
# 1142 . Predicting time step:  2014-12-18 13:00:00
# 1143 . Predicting time step:  2014-12-18 14:00:00
# 1144 . Predicting time step:  2014-12-18 15:00:00
# 1145 . Predicting time step:  2014-12-18 16:00:00
# 1146 . Predicting time step:  2014-12-18 17:00:00
# 1147 . Predicting time step:  2014-12-18 18:00:00
# 1148 . Predicting time step:  2014-12-18 19:00:00
# 1149 . Predicting time step:  2014-12-18 20:00:00
# 1150 . Predicting time step:  2014-12-18 21:00:00
# 1151 . Predicting time step:  2014-12-18 22:00:00
# 1152 . Predicting time step:  2014-12-18 23:00:00
# 1153 . Predicting time step:  2014-12-19 00:00:00
# 1154 . Predicting time step:  2014-12-19 01:00:00
# 1155 . Predicting time step:  2014-12-19 02:00:00
# 1156 . Predicting time step:  2014-12-19 03:00:00
# 1157 . Predicting time step:  2014-12-19 04:00:00
# 1158 . Predicting time step:  2014-12-19 05:00:00
# 1159 . Predicting time step:  2014-12-19 06:00:00
# 1160 . Predicting time step:  2014-12-19 07:00:00
# 1161 . Predicting time step:  2014-12-19 08:00:00
# 1162 . Predicting time step:  2014-12-19 09:00:00
# 1163 . Predicting time step:  2014-12-19 10:00:00
# 1164 . Predicting time step:  2014-12-19 11:00:00
# 1165 . Predicting time step:  2014-12-19 12:00:00
# 1166 . Predicting time step:  2014-12-19 13:00:00
# 1167 . Predicting time step:  2014-12-19 14:00:00
# 1168 . Predicting time step:  2014-12-19 15:00:00
# 1169 . Predicting time step:  2014-12-19 16:00:00
# 1170 . Predicting time step:  2014-12-19 17:00:00
# 1171 . Predicting time step:  2014-12-19 18:00:00
# 1172 . Predicting time step:  2014-12-19 19:00:00
# 1173 . Predicting time step:  2014-12-19 20:00:00
# 1174 . Predicting time step:  2014-12-19 21:00:00
# 1175 . Predicting time step:  2014-12-19 22:00:00
# 1176 . Predicting time step:  2014-12-19 23:00:00
# 1177 . Predicting time step:  2014-12-20 00:00:00
# 1178 . Predicting time step:  2014-12-20 01:00:00
# 1179 . Predicting time step:  2014-12-20 02:00:00
# 1180 . Predicting time step:  2014-12-20 03:00:00
# 1181 . Predicting time step:  2014-12-20 04:00:00
# 1182 . Predicting time step:  2014-12-20 05:00:00
# 1183 . Predicting time step:  2014-12-20 06:00:00
# 1184 . Predicting time step:  2014-12-20 07:00:00
# 1185 . Predicting time step:  2014-12-20 08:00:00
# 1186 . Predicting time step:  2014-12-20 09:00:00
# 1187 . Predicting time step:  2014-12-20 10:00:00
# 1188 . Predicting time step:  2014-12-20 11:00:00
# 1189 . Predicting time step:  2014-12-20 12:00:00
# 1190 . Predicting time step:  2014-12-20 13:00:00
# 1191 . Predicting time step:  2014-12-20 14:00:00
# 1192 . Predicting time step:  2014-12-20 15:00:00
# 1193 . Predicting time step:  2014-12-20 16:00:00
# 1194 . Predicting time step:  2014-12-20 17:00:00
# 1195 . Predicting time step:  2014-12-20 18:00:00
# 1196 . Predicting time step:  2014-12-20 19:00:00
# 1197 . Predicting time step:  2014-12-20 20:00:00
# 1198 . Predicting time step:  2014-12-20 21:00:00
# 1199 . Predicting time step:  2014-12-20 22:00:00
# 1200 . Predicting time step:  2014-12-20 23:00:00
# 1201 . Predicting time step:  2014-12-21 00:00:00
# 1202 . Predicting time step:  2014-12-21 01:00:00
# 1203 . Predicting time step:  2014-12-21 02:00:00
# 1204 . Predicting time step:  2014-12-21 03:00:00
# 1205 . Predicting time step:  2014-12-21 04:00:00
# 1206 . Predicting time step:  2014-12-21 05:00:00
# 1207 . Predicting time step:  2014-12-21 06:00:00
# 1208 . Predicting time step:  2014-12-21 07:00:00
# 1209 . Predicting time step:  2014-12-21 08:00:00
# 1210 . Predicting time step:  2014-12-21 09:00:00
# 1211 . Predicting time step:  2014-12-21 10:00:00
# 1212 . Predicting time step:  2014-12-21 11:00:00
# 1213 . Predicting time step:  2014-12-21 12:00:00
# 1214 . Predicting time step:  2014-12-21 13:00:00
# 1215 . Predicting time step:  2014-12-21 14:00:00
# 1216 . Predicting time step:  2014-12-21 15:00:00
# 1217 . Predicting time step:  2014-12-21 16:00:00
# 1218 . Predicting time step:  2014-12-21 17:00:00
# 1219 . Predicting time step:  2014-12-21 18:00:00
# 1220 . Predicting time step:  2014-12-21 19:00:00
# 1221 . Predicting time step:  2014-12-21 20:00:00
# 1222 . Predicting time step:  2014-12-21 21:00:00
# 1223 . Predicting time step:  2014-12-21 22:00:00
# 1224 . Predicting time step:  2014-12-21 23:00:00
# 1225 . Predicting time step:  2014-12-22 00:00:00
# 1226 . Predicting time step:  2014-12-22 01:00:00
# 1227 . Predicting time step:  2014-12-22 02:00:00
# 1228 . Predicting time step:  2014-12-22 03:00:00
# 1229 . Predicting time step:  2014-12-22 04:00:00
# 1230 . Predicting time step:  2014-12-22 05:00:00
# 1231 . Predicting time step:  2014-12-22 06:00:00
# 1232 . Predicting time step:  2014-12-22 07:00:00
# 1233 . Predicting time step:  2014-12-22 08:00:00
# 1234 . Predicting time step:  2014-12-22 09:00:00
# 1235 . Predicting time step:  2014-12-22 10:00:00
# 1236 . Predicting time step:  2014-12-22 11:00:00
# 1237 . Predicting time step:  2014-12-22 12:00:00
# 1238 . Predicting time step:  2014-12-22 13:00:00
# 1239 . Predicting time step:  2014-12-22 14:00:00
# 1240 . Predicting time step:  2014-12-22 15:00:00
# 1241 . Predicting time step:  2014-12-22 16:00:00
# 1242 . Predicting time step:  2014-12-22 17:00:00
# 1243 . Predicting time step:  2014-12-22 18:00:00
# 1244 . Predicting time step:  2014-12-22 19:00:00
# 1245 . Predicting time step:  2014-12-22 20:00:00
# 1246 . Predicting time step:  2014-12-22 21:00:00
# 1247 . Predicting time step:  2014-12-22 22:00:00
# 1248 . Predicting time step:  2014-12-22 23:00:00
# 1249 . Predicting time step:  2014-12-23 00:00:00
# 1250 . Predicting time step:  2014-12-23 01:00:00
# 1251 . Predicting time step:  2014-12-23 02:00:00
# 1252 . Predicting time step:  2014-12-23 03:00:00
# 1253 . Predicting time step:  2014-12-23 04:00:00
# 1254 . Predicting time step:  2014-12-23 05:00:00
# 1255 . Predicting time step:  2014-12-23 06:00:00
# 1256 . Predicting time step:  2014-12-23 07:00:00
# 1257 . Predicting time step:  2014-12-23 08:00:00
# 1258 . Predicting time step:  2014-12-23 09:00:00
# 1259 . Predicting time step:  2014-12-23 10:00:00
# 1260 . Predicting time step:  2014-12-23 11:00:00
# 1261 . Predicting time step:  2014-12-23 12:00:00
# 1262 . Predicting time step:  2014-12-23 13:00:00
# 1263 . Predicting time step:  2014-12-23 14:00:00
# 1264 . Predicting time step:  2014-12-23 15:00:00
# 1265 . Predicting time step:  2014-12-23 16:00:00
# 1266 . Predicting time step:  2014-12-23 17:00:00
# 1267 . Predicting time step:  2014-12-23 18:00:00
# 1268 . Predicting time step:  2014-12-23 19:00:00
# 1269 . Predicting time step:  2014-12-23 20:00:00
# 1270 . Predicting time step:  2014-12-23 21:00:00
# 1271 . Predicting time step:  2014-12-23 22:00:00
# 1272 . Predicting time step:  2014-12-23 23:00:00
# 1273 . Predicting time step:  2014-12-24 00:00:00
# 1274 . Predicting time step:  2014-12-24 01:00:00
# 1275 . Predicting time step:  2014-12-24 02:00:00
# 1276 . Predicting time step:  2014-12-24 03:00:00
# 1277 . Predicting time step:  2014-12-24 04:00:00
# 1278 . Predicting time step:  2014-12-24 05:00:00
# 1279 . Predicting time step:  2014-12-24 06:00:00
# 1280 . Predicting time step:  2014-12-24 07:00:00
# 1281 . Predicting time step:  2014-12-24 08:00:00
# 1282 . Predicting time step:  2014-12-24 09:00:00
# 1283 . Predicting time step:  2014-12-24 10:00:00
# 1284 . Predicting time step:  2014-12-24 11:00:00
# 1285 . Predicting time step:  2014-12-24 12:00:00
# 1286 . Predicting time step:  2014-12-24 13:00:00
# 1287 . Predicting time step:  2014-12-24 14:00:00
# 1288 . Predicting time step:  2014-12-24 15:00:00
# 1289 . Predicting time step:  2014-12-24 16:00:00
# 1290 . Predicting time step:  2014-12-24 17:00:00
# 1291 . Predicting time step:  2014-12-24 18:00:00
# 1292 . Predicting time step:  2014-12-24 19:00:00
# 1293 . Predicting time step:  2014-12-24 20:00:00
# 1294 . Predicting time step:  2014-12-24 21:00:00
# 1295 . Predicting time step:  2014-12-24 22:00:00
# 1296 . Predicting time step:  2014-12-24 23:00:00
# 1297 . Predicting time step:  2014-12-25 00:00:00
# 1298 . Predicting time step:  2014-12-25 01:00:00
# 1299 . Predicting time step:  2014-12-25 02:00:00
# 1300 . Predicting time step:  2014-12-25 03:00:00
# 1301 . Predicting time step:  2014-12-25 04:00:00
# 1302 . Predicting time step:  2014-12-25 05:00:00
# 1303 . Predicting time step:  2014-12-25 06:00:00
# 1304 . Predicting time step:  2014-12-25 07:00:00
# 1305 . Predicting time step:  2014-12-25 08:00:00
# 1306 . Predicting time step:  2014-12-25 09:00:00
# 1307 . Predicting time step:  2014-12-25 10:00:00
# 1308 . Predicting time step:  2014-12-25 11:00:00
# 1309 . Predicting time step:  2014-12-25 12:00:00
# 1310 . Predicting time step:  2014-12-25 13:00:00
# 1311 . Predicting time step:  2014-12-25 14:00:00
# 1312 . Predicting time step:  2014-12-25 15:00:00
# 1313 . Predicting time step:  2014-12-25 16:00:00
# 1314 . Predicting time step:  2014-12-25 17:00:00
# 1315 . Predicting time step:  2014-12-25 18:00:00
# 1316 . Predicting time step:  2014-12-25 19:00:00
# 1317 . Predicting time step:  2014-12-25 20:00:00
# 1318 . Predicting time step:  2014-12-25 21:00:00
# 1319 . Predicting time step:  2014-12-25 22:00:00
# 1320 . Predicting time step:  2014-12-25 23:00:00
# 1321 . Predicting time step:  2014-12-26 00:00:00
# 1322 . Predicting time step:  2014-12-26 01:00:00
# 1323 . Predicting time step:  2014-12-26 02:00:00
# 1324 . Predicting time step:  2014-12-26 03:00:00
# 1325 . Predicting time step:  2014-12-26 04:00:00
# 1326 . Predicting time step:  2014-12-26 05:00:00
# 1327 . Predicting time step:  2014-12-26 06:00:00
# 1328 . Predicting time step:  2014-12-26 07:00:00
# 1329 . Predicting time step:  2014-12-26 08:00:00
# 1330 . Predicting time step:  2014-12-26 09:00:00
# 1331 . Predicting time step:  2014-12-26 10:00:00
# 1332 . Predicting time step:  2014-12-26 11:00:00
# 1333 . Predicting time step:  2014-12-26 12:00:00
# 1334 . Predicting time step:  2014-12-26 13:00:00
# 1335 . Predicting time step:  2014-12-26 14:00:00
# 1336 . Predicting time step:  2014-12-26 15:00:00
# 1337 . Predicting time step:  2014-12-26 16:00:00
# 1338 . Predicting time step:  2014-12-26 17:00:00
# 1339 . Predicting time step:  2014-12-26 18:00:00
# 1340 . Predicting time step:  2014-12-26 19:00:00
# 1341 . Predicting time step:  2014-12-26 20:00:00
# 1342 . Predicting time step:  2014-12-26 21:00:00
# 1343 . Predicting time step:  2014-12-26 22:00:00
# 1344 . Predicting time step:  2014-12-26 23:00:00
# 1345 . Predicting time step:  2014-12-27 00:00:00
# 1346 . Predicting time step:  2014-12-27 01:00:00
# 1347 . Predicting time step:  2014-12-27 02:00:00
# 1348 . Predicting time step:  2014-12-27 03:00:00
# 1349 . Predicting time step:  2014-12-27 04:00:00
# 1350 . Predicting time step:  2014-12-27 05:00:00
# 1351 . Predicting time step:  2014-12-27 06:00:00
# 1352 . Predicting time step:  2014-12-27 07:00:00
# 1353 . Predicting time step:  2014-12-27 08:00:00
# 1354 . Predicting time step:  2014-12-27 09:00:00
# 1355 . Predicting time step:  2014-12-27 10:00:00
# 1356 . Predicting time step:  2014-12-27 11:00:00
# 1357 . Predicting time step:  2014-12-27 12:00:00
# 1358 . Predicting time step:  2014-12-27 13:00:00
# 1359 . Predicting time step:  2014-12-27 14:00:00
# 1360 . Predicting time step:  2014-12-27 15:00:00
# 1361 . Predicting time step:  2014-12-27 16:00:00
# 1362 . Predicting time step:  2014-12-27 17:00:00
# 1363 . Predicting time step:  2014-12-27 18:00:00
# 1364 . Predicting time step:  2014-12-27 19:00:00
# 1365 . Predicting time step:  2014-12-27 20:00:00
# 1366 . Predicting time step:  2014-12-27 21:00:00
# 1367 . Predicting time step:  2014-12-27 22:00:00
# 1368 . Predicting time step:  2014-12-27 23:00:00
# 1369 . Predicting time step:  2014-12-28 00:00:00
# 1370 . Predicting time step:  2014-12-28 01:00:00
# 1371 . Predicting time step:  2014-12-28 02:00:00
# 1372 . Predicting time step:  2014-12-28 03:00:00
# 1373 . Predicting time step:  2014-12-28 04:00:00
# 1374 . Predicting time step:  2014-12-28 05:00:00
# 1375 . Predicting time step:  2014-12-28 06:00:00
# 1376 . Predicting time step:  2014-12-28 07:00:00
# 1377 . Predicting time step:  2014-12-28 08:00:00
# 1378 . Predicting time step:  2014-12-28 09:00:00
# 1379 . Predicting time step:  2014-12-28 10:00:00
# 1380 . Predicting time step:  2014-12-28 11:00:00
# 1381 . Predicting time step:  2014-12-28 12:00:00
# 1382 . Predicting time step:  2014-12-28 13:00:00
# 1383 . Predicting time step:  2014-12-28 14:00:00
# 1384 . Predicting time step:  2014-12-28 15:00:00
# 1385 . Predicting time step:  2014-12-28 16:00:00
# 1386 . Predicting time step:  2014-12-28 17:00:00
# 1387 . Predicting time step:  2014-12-28 18:00:00
# 1388 . Predicting time step:  2014-12-28 19:00:00
# 1389 . Predicting time step:  2014-12-28 20:00:00
# 1390 . Predicting time step:  2014-12-28 21:00:00
# 1391 . Predicting time step:  2014-12-28 22:00:00
# 1392 . Predicting time step:  2014-12-28 23:00:00
# 1393 . Predicting time step:  2014-12-29 00:00:00
# 1394 . Predicting time step:  2014-12-29 01:00:00
# 1395 . Predicting time step:  2014-12-29 02:00:00
# 1396 . Predicting time step:  2014-12-29 03:00:00
# 1397 . Predicting time step:  2014-12-29 04:00:00
# 1398 . Predicting time step:  2014-12-29 05:00:00
# 1399 . Predicting time step:  2014-12-29 06:00:00
# 1400 . Predicting time step:  2014-12-29 07:00:00
# 1401 . Predicting time step:  2014-12-29 08:00:00
# 1402 . Predicting time step:  2014-12-29 09:00:00
# 1403 . Predicting time step:  2014-12-29 10:00:00
# 1404 . Predicting time step:  2014-12-29 11:00:00
# 1405 . Predicting time step:  2014-12-29 12:00:00
# 1406 . Predicting time step:  2014-12-29 13:00:00
# 1407 . Predicting time step:  2014-12-29 14:00:00
# 1408 . Predicting time step:  2014-12-29 15:00:00
# 1409 . Predicting time step:  2014-12-29 16:00:00
# 1410 . Predicting time step:  2014-12-29 17:00:00
# 1411 . Predicting time step:  2014-12-29 18:00:00
# 1412 . Predicting time step:  2014-12-29 19:00:00
# 1413 . Predicting time step:  2014-12-29 20:00:00
# 1414 . Predicting time step:  2014-12-29 21:00:00
# 1415 . Predicting time step:  2014-12-29 22:00:00
# 1416 . Predicting time step:  2014-12-29 23:00:00
# 1417 . Predicting time step:  2014-12-30 00:00:00
# 1418 . Predicting time step:  2014-12-30 01:00:00
# 1419 . Predicting time step:  2014-12-30 02:00:00
# 1420 . Predicting time step:  2014-12-30 03:00:00
# 1421 . Predicting time step:  2014-12-30 04:00:00
# 1422 . Predicting time step:  2014-12-30 05:00:00
# 1423 . Predicting time step:  2014-12-30 06:00:00
# 1424 . Predicting time step:  2014-12-30 07:00:00
# 1425 . Predicting time step:  2014-12-30 08:00:00
# 1426 . Predicting time step:  2014-12-30 09:00:00
# 1427 . Predicting time step:  2014-12-30 10:00:00
# 1428 . Predicting time step:  2014-12-30 11:00:00
# 1429 . Predicting time step:  2014-12-30 12:00:00
# 1430 . Predicting time step:  2014-12-30 13:00:00
# 1431 . Predicting time step:  2014-12-30 14:00:00
# 1432 . Predicting time step:  2014-12-30 15:00:00
# 1433 . Predicting time step:  2014-12-30 16:00:00
# 1434 . Predicting time step:  2014-12-30 17:00:00
# 1435 . Predicting time step:  2014-12-30 18:00:00
# 1436 . Predicting time step:  2014-12-30 19:00:00
# 1437 . Predicting time step:  2014-12-30 20:00:00
# 1438 . Predicting time step:  2014-12-30 21:00:00
# 1439 . Predicting time step:  2014-12-30 22:00:00
# 1440 . Predicting time step:  2014-12-30 23:00:00
# 1441 . Predicting time step:  2014-12-31 00:00:00
# CPU times: user 18h 34min 36s, sys: 8h 9min 30s, total: 1d 2h 44min 7s
# Wall time: 4h 51min 32s

# %% [markdown]
# Compare predictions to actual load

# %%
eval_df = pd.DataFrame(predictions, columns=['t+'+str(t) for t in range(1, HORIZON+1)])
eval_df['timestamp'] = test.index[0:len(test.index)-HORIZON+1]
eval_df = pd.melt(eval_df, id_vars='timestamp', value_name='prediction', var_name='h')
eval_df['actual'] = np.array(np.transpose(test_ts)).ravel()
eval_df[['prediction', 'actual']] = scaler.inverse_transform(eval_df[['prediction', 'actual']])
eval_df.head()
# Out:
#             timestamp    h  prediction   actual
# 0 2014-11-01 00:00:00  t+1    2,508.87 2,514.00
# 1 2014-11-01 01:00:00  t+1    2,395.71 2,434.00
# 2 2014-11-01 02:00:00  t+1    2,407.74 2,390.00
# 3 2014-11-01 03:00:00  t+1    2,381.71 2,382.00
# 4 2014-11-01 04:00:00  t+1    2,463.96 2,419.00

# %% [markdown]
# Compute the mean absolute percentage error over all predictions

# %%
if(HORIZON > 1):
    eval_df['APE'] = (eval_df['prediction'] - eval_df['actual']).abs() / eval_df['actual']
    print(eval_df.groupby('h')['APE'].mean())
# Out:
# h
# t+1    0.01
# t+10   0.05
# t+11   0.05
# t+12   0.05
# t+13   0.05
# t+14   0.05
# t+15   0.06
# t+16   0.06
# t+17   0.06
# t+18   0.06
# t+19   0.06
# t+2    0.02
# t+20   0.06
# t+21   0.07
# t+22   0.07
# t+23   0.07
# t+24   0.07
# t+3    0.03
# t+4    0.03
# t+5    0.04
# t+6    0.04
# t+7    0.04
# t+8    0.05
# t+9    0.05
# Name: APE, dtype: float64

# %%
print('One step forecast MAPE: ', (mape(eval_df[eval_df['h'] == 't+1']['prediction'], eval_df[eval_df['h'] == 't+1']['actual']))*100, '%')
# Out:
# One step forecast MAPE:  0.9198698774852749 %

# %%
print('One step forecast MAPE: ', mape(eval_df['prediction'], eval_df['actual'])*100, '%')
# Out:
# One step forecast MAPE:  4.973729251357043 %

# %% [markdown]
# Plot the predictions vs the actuals for the first week of the test set

# %%
if(HORIZON == 1):
    ## Plotting single step forecast
    eval_df.plot(x='timestamp', y=['actual', 'prediction'], style=['r', 'b'], figsize=(15, 8))

else:
    ## Plotting multi step forecast
    plot_df = eval_df[(eval_df.h=='t+1')][['timestamp', 'actual']]
    for t in range(1, HORIZON+1):
        plot_df['t+'+str(t)] = eval_df[(eval_df.h=='t+'+str(t))]['prediction'].values

    fig = plt.figure(figsize=(15, 8))
    ax = plt.plot(plot_df['timestamp'], plot_df['actual'], color='red', linewidth=4.0)
    ax = fig.add_subplot(111)
    for t in range(1, HORIZON+1):
        x = plot_df['timestamp'][(t-1):]
        y = plot_df['t+'+str(t)][0:len(x)]
        ax.plot(x, y, color='blue', linewidth=4*math.pow(.9,t), alpha=math.pow(0.8,t))
    
    ax.legend(loc='best')
    
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()
